# %% [markdown]
# # Aufgabe 1) - Das beste k bestimmen

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
url = 'https://raw.githubusercontent.com/SpectaGodX/DataScience/master/dataset_kmean.csv'
data = pd.read_csv(url, error_bad_lines=False)
data.head()
# Out:
#          V1        V2        V3
# 0 -5.340236  4.747246  3.823326
# 1 -9.587065 -3.434466  9.701839
# 2 -8.385012 -3.902794  8.514620
# 3  5.708226  2.658575  5.404482
# 4 -7.431665 -4.390251  9.003216

# %%
mms = MinMaxScaler()
mms.fit(data)
data_transformed = mms.transform(data)

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ## Dem Diagramm kann entnommen werden, dass das beste k bei 5 liegt.

# %% [markdown]
# # Aufgabe 2) - Clustering Vector anzeigen

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
url = 'https://raw.githubusercontent.com/SpectaGodX/DataScience/master/dataset_kmean.csv'
data = pd.read_csv(url, error_bad_lines=False)
data.head()
# Out:
#          V1        V2        V3
# 0 -5.340236  4.747246  3.823326
# 1 -9.587065 -3.434466  9.701839
# 2 -8.385012 -3.902794  8.514620
# 3  5.708226  2.658575  5.404482
# 4 -7.431665 -4.390251  9.003216

# %%
# Getting the values and plotting it
f1 = data['V1'].values
f2 = data['V2'].values
f3 = data['V3'].values
X = np.array(list(zip(f1, f2, f3)))
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2])
